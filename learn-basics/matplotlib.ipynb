# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# ## Let do some works

# %%
plt.plot(np.arange(5), "ro");
plt.ylabel("fuuny numbers")
plt.xlabel("not funny numbers")
# Out:
# Text(0.5, 0, 'not funny numbers')

# %%
data = {
    'a': np.random.randn(5000),
    'b': np.arange(5000)
}

plt.scatter(data["b"], data["a"])
